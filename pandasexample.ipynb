# %%
import pandas as pd

# %%
# Read the data from a csv file into a dataframe
df = pd.read_csv(r"C:\Users\budha\Downloads\sales_data_sample.csv", encoding="latin1")
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# Read the data from a excel file into a dataframe
df = pd.read_excel(r"C:\Users\budha\Downloads\SampleSuperstore.xlsx")
print(df)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# Import json file into a Dataframe
df = pd.read_json(r"C:\Users\budha\Downloads\sample_Data.json")
df
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
import pandas as pd

data = {
    "Name" : ['Sujan', 'Ram', 'Hari'],
    "Age" : [20,30,40],
    "City" : ["Pokhara", "Kathmandu", "Butwal"]
}

df = pd.DataFrame(data)
df
# Out:
#     Name  Age       City
# 0  Sujan   20    Pokhara
# 1    Ram   30  Kathmandu
# 2   Hari   40     Butwal

# %%
df.to_csv('output.csv', index = False)

# %%
df
# Out:
#     Name  Age       City
# 0  Sujan   20    Pokhara
# 1    Ram   30  Kathmandu
# 2   Hari   40     Butwal

# %%
df = pd.read_csv('output.csv')
df
# Out:
#     Name  Age       City
# 0  Sujan   20    Pokhara
# 1    Ram   30  Kathmandu
# 2   Hari   40     Butwal

# %%
df.reset_index(inplace=True)

# %%
import pandas as pd

data = {
    'Product': ['Apple', 'Banana'], 
    'Amount': [100, 80]
    }
df = pd.DataFrame(data)

df.to_csv("test_output.csv", index=False)

# %%
df = pd.read_csv('test_output.csv')

# %%
df
# Out:
#   Product  Amount
# 0   Apple     100
# 1  Banana      80

# %%
# to see the records in the dataset : head() and tail()

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\budha\Downloads\sales_data_sample.csv", encoding = "latin1")
print("Display first 5 rows" )
df.head()
# Out:
# Display first 5 rows
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
print("Display first 10 rows")
df.head(10)
# Out:
# Display first 10 rows
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# ...

# %%
print("Display last 5 rows")
df.tail()
# Out:
# Display last 5 rows
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#            ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2818  12/2/2004 0:00   Shipped       4        12     2004  ...
# 2819  1/31/2005 0:00   Shipped       1         1     2005  ...
# 2820   3/1/2005 0:00  Resolved       1         3     2005  ...
# 2821  3/28/2005 0:00   Shipped       1         3     2005  ...
# 2822   5/6/2005 0:00   On Hold       2         5     2005  ...
#
#                ADDRESSLINE1  ADDRESSLINE2      CITY STATE POSTALCODE  COUNTRY  \
# ...

# %%
print("Display last 10 rows")
df.tail(10)
# Out:
# Display last 10 rows
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2813        10293               32      60.06                1  1921.92
# 2814        10306               35      59.51                6  2082.85
# 2815        10315               40      55.69                5  2227.60
# 2816        10327               37      86.74                4  3209.38
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 2813    9/9/2004 0:00   Shipped       3         9     2004  ...
# ...

# %%
df = pd.read_json(r"C:\Users\budha\Downloads\sample_Data.json")
df
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
df.head()
# Out:
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00  Electronics
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00  Electronics
#
#                                                image
# 0  https://www.apple.com/newsroom/images/product/...
# 1  https://images.samsung.com/is/image/samsung/p6...
# ...

# %%
filtered_price = df[df['price'] > 900]
filtered_price.head(3)
# Out:
#    id                               name  \
# 0   1                    Apple iPhone 12
# 3   4  LG OLED55CXPUA 55-inch 4K OLED TV
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
#
#                                                image
# 0  https://www.apple.com/newsroom/images/product/...
# 3  https://www.lg.com/us/images/tvs/md07501804/ga...

# %%
# Understanding the data in the datasets
# columns, rows
# what type of data type ?
# missing data ?

# info() methods

# %%
df = pd.read_json(r"C:\Users\budha\Downloads\sample_Data.json")
print("Displaying the data sets info")
df.info()
# Out:
# Displaying the data sets info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   name         20 non-null     object
#  2   description  20 non-null     object
#  3   price        20 non-null     float64
#  4   category     20 non-null     object
#  5   image        20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB

# %%
# Describe methods in pandas

data = {
    'Product': ['Apple', 'Banana', 'Orange', 'Banana', 'Apple'],
    'Price': [100, 150, 120, 130, 100]
}

df = pd.DataFrame(data)
df.describe()
# Out:
#             Price
# count    5.000000
# mean   120.000000
# std     21.213203
# min    100.000000
# 25%    100.000000
# 50%    120.000000
# 75%    130.000000
# max    150.000000

# %%
df = pd.read_json(r"C:\Users\budha\Downloads\sample_Data.json")
print("Displaying the data sets info")
df.shape
# Out:
# Displaying the data sets info
# (20, 6)

# %%
df.columns
# Out:
# Index(['id', 'name', 'description', 'price', 'category', 'image'], dtype='object')

# %%
df.size
# Out:
# 120

# %%
df.ndim
# Out:
# 2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %%
# select specific columns

# %%
df.head()
# Out:
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00  Electronics
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00  Electronics
#
#                                                image
# 0  https://www.apple.com/newsroom/images/product/...
# 1  https://images.samsung.com/is/image/samsung/p6...
# ...

# %%
# Selecting the single column from the datasets
df['price']
# Out:
# 0      999.00
# 1      799.00
# 2      499.99
# 3     1599.99
# 4      299.00
# 5      229.95
# 6      399.99
# 7      699.99
# 8      279.99
# 9      899.00
# 10     249.00
# 11     299.00
# 12     129.95
# 13     399.99
# 14     349.99
# 15     699.95
# 16     169.99
# 17     799.99
# 18     209.99
# 19     139.99
# Name: price, dtype: float64

# %%
# Selecting the multiples column
df[['price', 'name']]
# Out:
#       price                                               name
# 0    999.00                                    Apple iPhone 12
# 1    799.00                                 Samsung Galaxy S21
# 2    499.99                                 Sony PlayStation 5
# 3   1599.99                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    299.00        Bose QuietComfort 35 II Wireless Headphones
# 5    229.95                          Fitbit Versa 3 Smartwatch
# 6    399.99                             KitchenAid Stand Mixer
# 7    699.99                 Dyson V11 Absolute Cordless Vacuum
# 8    279.99                         Ninja Foodi Smart XL Grill
# 9    899.00                    Canon EOS Rebel T8i DSLR Camera
# 10   249.00                                  Apple AirPods Pro
# 11   299.00        Bose QuietComfort 35 II Wireless Headphones
# 12   129.95                    Fitbit Charge 4 Fitness Tracker
# 13   399.99                              Samsung Galaxy Watch3
# ...

# %%
# Filtering the rows based on the conditions
df = pd.read_json(r"C:\Users\budha\Downloads\sample_Data.json")
print("Displaying the data sets info")
df.head(10)
print("Displaying the filterd rows")
filtered_rows = df[df['price'] >= 220 ]
filtered_rows
# Out:
# Displaying the data sets info
# Displaying the filterd rows
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
df = pd.read_json(r"C:\Users\budha\Downloads\sample_Data.json")

print("Displaying the filterd rows")

filtered_category = df[df['category'] == 'Electronics']
filtered_category
# Out:
# Displaying the filterd rows
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
#
#                                           description    price     category  \
# 0   The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# ...

# %%
df = pd.read_json(r"C:\Users\budha\Downloads\sample_Data.json")

print("Displaying the filterd rows")
filtered_price = df[(df['price'] >= 500) & (df['price'] <= 1000)]
filtered_price
# Out:
# Displaying the filterd rows
#     id                                       name  \
# 0    1                            Apple iPhone 12
# 1    2                         Samsung Galaxy S21
# 7    8         Dyson V11 Absolute Cordless Vacuum
# 9   10            Canon EOS Rebel T8i DSLR Camera
# 15  16  Breville Barista Express Espresso Machine
# 17  18             iRobot Roomba i7+ Robot Vacuum
#
#                                           description   price  \
# 0   The Apple iPhone 12 features a 6.1-inch Super ...  999.00
# 1   The Samsung Galaxy S21 features a 6.2-inch Dyn...  799.00
# 7   The Dyson V11 Absolute Cordless Vacuum feature...  699.99
# 9   The Canon EOS Rebel T8i DSLR Camera features a...  899.00
# 15  The Breville Barista Express Espresso Machine ...  699.95
# 17  The iRobot Roomba i7+ Robot Vacuum features au...  799.99
#
#            category                                              image
# 0       Electronics  https://www.apple.com/newsroom/images/product/...
# ...
